# %% [markdown]
# <a href="https://colab.research.google.com/github/Jyotibaberwal/Matrix-computation-for-data-science/blob/main/Assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **The following code generates the cat’s picture**
#
# Do the following for each transformation below:
#
# A. create the matrix associated to the given transformation
#
# B. show the effect of applying this matrix to the picture.

# %%
import numpy as np
import matplotlib.pyplot as plt
topx=np.array([1, .98, .8, .83, .8, .77, .5, .25, 0, -.25, -.5, -.8, -.8, -.98, -1])

topy=np.array([0, .15, .7, 1.15, 1.03, 1.15, .85, .95, 1, .95, .85, 1.2, .7, .15, 0])
botx=-np.cos(np.pi*np.arange(1,10)/10)
boty=-np.sin(np.pi*np.arange(1,10)/10)
wiskx=np.array([.2, 1.3, .2, 1.4, .2, 1.4, .2, 1.3, .2, .17, .13, .08, .03, 0])
wisky=np.array([ 0, .3, 0, .1, 0, -.1, 0, -.3, 0, .1, -.1, .1, -.1, 0]) -.2
xeye=np.array([0, .2, .3, .4, .43, .45, .43, .4, .37, .35, .37, .4, .5, .6, .5, .4, .3, .2,
0])
yeye=np.array([.5, .5, .43, .4, .42, .5, .58, .6, .58, .5, .42, .4, .43, .5, .57, .6, .57,
.5,.5])-.2
x=np.concatenate((topx,botx,wiskx,xeye,-xeye,-wiskx[::-1]))
y=np.concatenate((topy,boty,wisky,yeye, yeye,wisky[::-1]))
cat = np.array([x,y]).T
plt.plot(cat[:,0], cat[:,1],'b')
plt.xlim(-2, 2)
plt.ylim(-2, 2)
plt.show()

# %% [markdown]
# **a. Reflection though the x-axis**

# %%
t_x = np.array([[1, 0], [0, -1]])
reflected_cat = np.dot(cat,t_x)

plt.plot(reflected_cat[:,0], reflected_cat[:,1],'b')
plt.xlim(-2, 2)
plt.ylim(-2, 2)
plt.show()

# %% [markdown]
# **b. Reflection though the y-axis**

# %%
t_y = np.array([[-1, 0], [0, 1]])
reflected_cat = np.dot(cat, t_y)

plt.plot(reflected_cat[:,0], reflected_cat[:,1],'b')
plt.xlim(-2, 2)
plt.ylim(-2, 2)
plt.show()

# %% [markdown]
# **c. Reflection though the axis y=x**

# %%
t_y_equals_x = np.array([[0, 1], [1, 0]])
reflected_cat = np.dot(cat, t_y_equals_x)

plt.plot(reflected_cat[:,0], reflected_cat[:,1],'b')
plt.xlim(-2, 2)
plt.ylim(-2, 2)
plt.show()

# %% [markdown]
# **d. Reflection through the line y=-x:**

# %%
t_y_neg_x = np.array([[0, -1], [-1, 0]])
reflected_cat = np.dot(cat, t_y_neg_x)

plt.plot(reflected_cat[:,0], reflected_cat[:,1],'b')
plt.xlim(-2, 2)
plt.ylim(-2, 2)
plt.show()

# %% [markdown]
# **e. Reflection through the origin**

# %%
t_origin = np.array([[-1, 0], [0, -1]])
reflected_cat = np.dot(cat, t_origin)

plt.plot(reflected_cat[:,0], reflected_cat[:,1],'b')
plt.xlim(-2, 2)
plt.ylim(-2, 2)
plt.show()

# %% [markdown]
# **f. Horizontal Contraction by a factor ⅓**

# %%
t_h_contraction = np.array([[1/3, 0], [0, 1]])
contracted_cat = np.dot(cat, t_h_contraction)

plt.plot(contracted_cat[:,0], contracted_cat[:,1],'b')
plt.xlim(-2, 2)
plt.ylim(-2, 2)
plt.show()

# %% [markdown]
# **g. Vertical Contraction by a factor ⅕**

# %%
t_v_contraction = np.array([[1, 0], [0, 1/5]])
contracted_cat = np.dot(cat, t_v_contraction)

plt.plot(contracted_cat[:,0], contracted_cat[:,1],'b')
plt.xlim(-2, 2)
plt.ylim(-2, 2)
plt.show()

# %% [markdown]
# **h. Horizontal Expansions by a factor 3**

# %%
t_h_expansion = np.array([[3, 0], [0, 1]])
expanded_cat = np.dot(cat, t_h_expansion)

plt.plot(expanded_cat[:,0], expanded_cat[:,1],'b')
plt.xlim(-5, 5)
plt.ylim(-5, 5)
plt.show()

# %% [markdown]
# **i. Vertical Expansions by a factor of 4**

# %%
t_v_expansion = np.array([[1, 0], [0, 4]])
expanded_cat = np.dot(cat, t_v_expansion)

plt.plot(expanded_cat[:,0], expanded_cat[:,1],'b')
plt.xlim(-5, 5)
plt.ylim(-5, 5)
plt.show()

# %% [markdown]
# **j. Horizontal Shears by a factor of -1.5 then +1.5**

# %%
## factor = -1.5
horizontal_shear_neg = np.array([[-1.5, 1], [1, 0]])
sheared_cat_neg = np.dot(cat, horizontal_shear_neg)

plt.plot(sheared_cat_neg[:,0], sheared_cat_neg[:,1],'b')
plt.xlim(-4 ,4)
plt.ylim(-4, 4)
plt.show()

## factor = 1.5
horizontal_shear_pos = np.array([[1.5, 1], [1, 0]])
sheared_cat_pos = np.dot(cat, horizontal_shear_pos)

plt.plot(sheared_cat_pos[:,0], sheared_cat_pos[:,1],'b')
plt.xlim(-4, 4)
plt.ylim(-4, 4)
plt.show()

# %% [markdown]
# **k. Vertical Shears by a factor of -1.5 then +1.5**

# %%
vertical_shear_neg = np.array([[1, -1.5], [0, 1]])
sheared_cat_neg = np.dot(cat, vertical_shear_neg)

plt.plot(sheared_cat_neg[:,0], sheared_cat_neg[:,1],'b')
plt.xlim(-4, 4)
plt.ylim(-4, 4)
plt.show()

vertical_shear_pos = np.array([[1, 1.5], [0, 1]])
sheared_cat_pos = np.dot(cat, vertical_shear_pos)

plt.plot(sheared_cat_pos[:,0], sheared_cat_pos[:,1],'b')
plt.xlim(-4, 4)
plt.ylim(-4, 4)
plt.show()

# %% [markdown]
# **2) Roatation of matrix**
#
#   a) Anticlockwise

# %%
import numpy as np
import matplotlib.pyplot as plt

theta = np.deg2rad(30)   # Convert angle to radians

# Rotation matrix
rotation_matrix = np.array([[np.cos(theta), -np.sin(theta)], [np.sin(theta), np.cos(theta)]])

v = np.array([1, 2])

rotated_v = np.dot(rotation_matrix, v)  # Apply rotation

## plotting
w = rotated_v[0]
s = rotated_v[1]

u = [1]
v = [2]

plt.quiver(0, 0, u, v, color='b', units='xy', scale=1)
plt.quiver(0,0,w,s,color ='r',units ='xy',scale=1)
plt.xlim(-2, 5)
plt.ylim(-2, 2.5)


print("Rotated vector:", rotated_v)
# Out:
# Rotated vector: [-0.1339746   2.23205081]

# %% [markdown]
# b.) clockwise

# %%
import numpy as np
import matplotlib.pyplot as plt

theta = np.deg2rad(-45)  # Convert angle to radians
rotation_matrix = np.array([[np.cos(theta), -np.sin(theta)], [np.sin(theta), np.cos(theta)]])

v = np.array([1, 2])

# Apply rotation
rotated_v = np.dot(rotation_matrix, v)
w = rotated_v[0]
s = rotated_v[1]

## plotting
u = [1]
v = [2]

plt.quiver(0, 0, u, v, color='b', units='xy', scale=1)
plt.quiver(0,0,w,s,color ='r',units ='xy',scale=1)
plt.xlim(0, 5)
plt.ylim(0,5)


print("Rotated vector:", rotated_v)

# %% [markdown]
# C.) Shear along x-axis

# %%
import numpy as np
import matplotlib.pyplot as plt

v = np.array([2, 4])

shear_matrix = np.array([[1, 2], [0, 1]])  # we took shear factor as 2

resultant_vector = np.dot(shear_matrix, v)

##plotting
u = [2]
v = [4]

w = resultant_vector[0]
s = resultant_vector[1]

plt.quiver(0, 0, u, v, color='b', units='xy', scale=1)
plt.quiver(0,0,resultant_vector[0],s,color ='r',units ='xy',scale=1)
plt.xlim(0, 10)
plt.ylim(0, 10)

# %% [markdown]
# # Question 3
# **Let T: R3 → R3. ( Use vector v = [2, 4, 1] for the visualization )**
#
# a) If T(a, b, c)=(a, b, 0), show that T is the projection on the xy plane along
# the z-axis.

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

v = np.array([2, 4, 1])
fig = plt.figure()
ax = fig.add_subplot(111,projection = "3d")

ax.quiver(0, 0, 0, v[0], v[1], v[2], color='b',label = 'v')
ax.quiver(0,0,0,v[0],v[1],0,color='r',label = 'T(v)')

ax.set_title('Projection on the xy-plane along the z-axis')
ax.set_xlabel('X')
ax.set_xlim(0,5)
ax.set_ylabel('Y')
ax.set_ylim(0,5)
ax.set_zlabel('Z')
ax.set_zlim(0,5)

ax.legend()
plt.show()

# %% [markdown]
# b. Find a formula for T(a, b, c), where T represents the scaling along the x
# and z-axis by a factor of 3.

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

v = np.array([2, 4, 1])
T_scale = np.array([[3,0,0],[0,1,0],[0,0,3]])
scaled_matrix = np.dot(T_scale,v)
fig = plt.figure()
ax = fig.add_subplot(111,projection = "3d")

ax.quiver(0, 0, 0, v[0], v[1], v[2], color='b',label = 'v')
ax.quiver(0,0,0,scaled_matrix[0],scaled_matrix[1],scaled_matrix[2],color='r',label = 'T(v)')

ax.set_title('Projection on the xy-plane along the z-axis')
ax.set_xlabel('X')
ax.set_xlim(0,5)
ax.set_ylabel('Y')
ax.set_ylim(0,5)
ax.set_zlabel('Z')
ax.set_zlim(0,5)


plt.show()

# %% [markdown]
# c) If T(a, b, c)=(a − c, b, 0), show that T is the projection on the xy-plane
# along the line L = {(a, 0, a): a ∈ R}.

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

v = np.array([2, 4, 1])
T_scale = np.array([[1,0,-1],[0,1,0],[0,0,0]])
scaled_matrix = np.dot(T_scale,v)
fig = plt.figure()
ax = fig.add_subplot(111,projection = "3d")

ax.quiver(0, 0, 0, v[0], v[1], v[2], color='b',label = 'v')
ax.quiver(0,0,0,scaled_matrix[0],scaled_matrix[1],scaled_matrix[2],color='r',label = 'T(v)')

ax.set_title('Projection on the xy-plane along the z-axis')
ax.set_xlabel('X')
ax.set_xlim([0,4])

ax.set_ylabel('Y')
ax.set_ylim([0,4])

ax.set_zlabel('Z')
ax.set_zlim([0,4])


plt.show()

# %% [markdown]
# d.) Find a formula for T(a,b,c), where T represent 3D shearing in the X-axis

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

v = np.array([2,4,1])


T_shear = np.array([[1,1,1],[0,1,0],[0,0,1]]) #shearing factor for y and z are 1
shear_v = np.dot(T_shear,v)
fig = plt.figure()
ax = fig.add_subplot(111,projection = "3d")

ax.quiver(0, 0, 0, v[0], v[1], v[2], color='b',label = 'v')
ax.quiver(0,0,0,shear_v[0],shear_v[1],shear_v[2],color='r',label = 'T(v)')

ax.set_title('Projection on the xy-plane along the z-axis')
ax.set_xlabel('X')
ax.set_xlim([0,10])

ax.set_ylabel('Y')
ax.set_ylim([0,10])

ax.set_zlabel('Z')
ax.set_zlim([0,10])

plt.legend()
plt.show()

# %% [markdown]
# # Question 4
# A.) Calculate the eigenvalues and corresponding eigenvectors of matrix A.
#
# f) Create a visualization that shows the original and transformed
# eigenvectors:
#
#       i) In the first subplot, display the original eigenvectors as arrows on a 2D plane
#
#       ii) In the second subplot, show the transformed eigenvectors after
#           applying matrix A as arrows on the same 2D plane.
#
#       iii) Ensure that both subplots have appropriate axis labels, titles, and legends.
# g) Explain what happens to the eigenvectors when matrix A is applied as a linear transformation based on your visualization.
#
# h) Describe how the concept of eigenvectors being stretched (scaled) but not rotated as illustrated in the visualization.

# %%
import numpy as np
v = np.array([[3,1],
             [1,3]])

eg_values,eg_vectors = np.linalg.eig(v)
# Out:
# [4. 2.]
# [[ 0.70710678 -0.70710678]
#  [ 0.70710678  0.70710678]]

# %% [markdown]
# Original eigenvectors and Transformed eigen vectors

# %%
import numpy as np
v = np.array([[3,1],
             [1,3]])

eg_values,eg_vectors = np.linalg.eig(v)

## original
plt.subplot(221,label = "original")
plt.quiver(0,0,eg_vectors[0,0],eg_vectors[1,0],color ='b',label ='eigne_vector_1',scale =5)
plt.quiver(0,0,eg_vectors[0,1],eg_vectors[1,1],label = 'eigen_vector_2',color = 'r',scale = 5)
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.title("Original")


## transformend
plt.subplot(222,label = "transformed")
transformed_egvector = np.dot(v,eg_vectors)
plt.quiver(0,0,transformed_egvector[0,0],transformed_egvector[1,0],color ='b',label ='T_eg_vector_1',scale =8)
plt.quiver(0,0,transformed_egvector[0,1],transformed_egvector[1,1],label = 'T_EgVector_2',color = 'r',scale = 8)
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.title('original')
# Out:
# Text(0.5, 1.0, 'original')

# %% [markdown]
# G.) After apllying linear transformation on eigen vectors, the eigen vectors streatched but not Rotated.
#
# E.) The eigen vectors doesn't rotated because when we do linear transformation of eigen vector it results in the scaling of that vector because of its definition that is  A.v = c.V  where c is scaler.
